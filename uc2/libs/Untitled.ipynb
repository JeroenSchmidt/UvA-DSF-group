# %%
import pandas as pd

# %%
pd.read_pickle("../data/Visual_well_being/anp.pickle")
# Out:
#                               image_id           anp_label  anp_sentiment  \
# 0         951727030670259635_143763900            hot_boys          0.017
# 1         951727030670259635_143763900        young_couple          0.019
# 2         951727030670259635_143763900       dirty_laundry         -0.263
# 3         951727030670259635_143763900         global_mall         -0.031
# 4         951728575726873168_289794729          high_boots          0.025
# 5         951728575726873168_289794729          funny_pets          0.078
# 6         951728575726873168_289794729         slow_motion         -0.064
# 7         951728575726873168_289794729           funny_dog          0.156
# 8         951728575726873168_289794729       working_group          0.008
# 9         951731159501174327_143763900         old_friends          0.543
# 10        951731159501174327_143763900       close_friends          0.558
# 11        951731159501174327_143763900          early_days         -0.005
# ...
